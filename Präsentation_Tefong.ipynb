# %% [markdown]
# <a href="https://colab.research.google.com/github/Tefong35/TefongEugene/blob/main/Pr%C3%A4sentation_Tefong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-pptx
from pptx import Presentation

#Präsentation starten
prs = Presentation()

#Folieninhalt
slides = [
    ("Datengetriebenes Kundenbeziehungsmanagement mit Python", [
        "Ein datenbasierter Ansatz – Data Science Projekt"
    ]),
    ("Ziel", [
        "Analyse von Nutzerverhalten und Segmentierung zur Wertsteigerung",
        "Kundenbindung & Marketingeffizienz steigern",
        "Optimierung der Kundenbindung",
        "Zielgruppenspezifische Ansprache",
        "Personalisierte Angebote ermöglichen"
    ]),
    ("Datenquellen & Merkmale", [
        "Medienplattform: Artikelkonsum, Verweildauer, Bindungsdauer",
        "Produktplattform: Webinare, E-Learnings, Videos, Kursfortschritt",
        "CRM-Daten: Registrierungen, Supportanfragen, Kaufhistorie",
        "Geodaten: PLZ, Ort, Region",
        "Sozialdemographische Daten: Altersgruppe, Beruf etc."
    ]),
    ("Vorgehensweise (CRM mit Python)", [
        "1. Datensammlung und -integration",
        "2. Datenbereinigung und Feature Engineering",
        "3. Explorative Datenanalyse (EDA)",
        "4. Kundenwertanalyse (RFM)",
        "5. Clusteranalyse (z. B. KMeans)",
        "6. Klassifikationsmodelle (z. B. Churn Prediction)",
        "7. Visualisierung & Handlungsempfehlungen"
    ]),
    ("Methodik", [
        "K-Means / DBSCAN Clustering",
        "RFM-Segmentierung",
        "Visualisierung mit PCA"
    ]),
    ("Use Case – Kundenwertanalyse & Segmentierung", [
        "Kundenbindung: RFM-Analyse (Recency, Frequency, Monetary)",
        "Segmentierung: K-Means-Clustering auf Verhaltensdaten",
        "Vorhersage: Klassifikation zur Churn-Prävention"
    ]),
    ("Ergebnisse (Beispiel)", [
        "Conversion-Steigerung: +25 %",
        "Abwanderung reduziert um 15 %",
        "Zielgruppen mit hohem Potenzial erkannt"
    ]),
    ("Ausblick", [
        "Lookalike Modeling",
        "Kunden-Lebenszeitwert (CLV) Prognose",
        "Generative KI für Ansprache"
    ]),
    ("Angebot", [
        "Wir helfen Ihnen, Ihre Kundendaten nutzbar zu machen.",
        "Für Vertrieb, Marketing & strategische Entscheidungen."
    ])
]

#Folien erzeugen
for title, content in slides:
    slide_layout = prs.slide_layouts[1]
    slide = prs.slides.add_slide(slide_layout)
    slide.shapes.title.text = title
    body = slide.placeholders[1]
    body.text = "\n".join(content)

#Präsentation speichern
prs.save("Kundensegmentierung_CRM_Praesentation.pptx")
